# %% [markdown]
# **You can use
# any packages that come as a default option with Anaconda. If you use an
# artificial neural network, the preference is Pytorch, but you are free to you use
# other packages. I need to be able to run your implementation on my machine
# or online (e.g., Google Colab). So, be sure to get approval from me for any
# special packages!**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Change this path to your shared location
SHARED_PATH = "/content/drive/MyDrive/Group Project"

# Ensure the directory exists
os.makedirs(SHARED_PATH, exist_ok=True)

print(f"Shared path is ready at: {SHARED_PATH}")

# %cd /content/drive/MyDrive/Group\ Project
# Out:
# Shared path is ready at: /content/drive/MyDrive/Group Project
# /content/drive/.shortcut-targets-by-id/1WIqvp-iVEF7lgpodL82Np2HHkI81rUym/Group Project

# %%
# !mkdir -p DCASE23_Task2_Vehicle_Sound_Event_Detection
# %cd DCASE23_Task2_Vehicle_Sound_Event_Detection

# !git init
# Out:
# /content/drive/.shortcut-targets-by-id/1WIqvp-iVEF7lgpodL82Np2HHkI81rUym/Group Project/DCASE23_Task2_Vehicle_Sound_Event_Detection
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/.shortcut-targets-by-id/1WIqvp-iVEF7lgpodL82Np2HHkI81rUym/Group Project/DCASE23_Task2_Vehicle_Sound_Event_Detection/.git/

# %%
# !git submodule add https://huggingface.co/datasets/renumics/dcase23-task2-enriched data/dcase23_dataset
# Out:
# Cloning into '/content/drive/.shortcut-targets-by-id/1WIqvp-iVEF7lgpodL82Np2HHkI81rUym/Group Project/DCASE23_Task2_Vehicle_Sound_Event_Detection/data/dcase23_dataset'...
# remote: Enumerating objects: 306, done.
# remote: Counting objects: 100% (306/306), done.
# remote: Compressing objects: 100% (139/139), done.
# remote: Total 306 (delta 165), reused 306 (delta 165), pack-reused 0 (from 0)
# Receiving objects: 100% (306/306), 750.32 KiB | 4.34 MiB/s, done.
# Resolving deltas: 100% (165/165), done.
# fatal: cannot exec '/content/drive/.shortcut-targets-by-id/1WIqvp-iVEF7lgpodL82Np2HHkI81rUym/Group Project/DCASE23_Task2_Vehicle_Sound_Event_Detection/.git/modules/data/dcase23_dataset/hooks/post-checkout': Permission denied
# fatal: unable to checkout submodule 'data/dcase23_dataset'

# %%
# !git submodule deinit -f data/dcase23_dataset
# Out:
# error: pathspec 'data/dcase23_dataset' did not match any file(s) known to git

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/.shortcut-targets-by-id/1WIqvp-iVEF7lgpodL82Np2HHkI81rUym/Group Project/DCASE23_Task2_Vehicle_Sound_Event_Detection/.git/

# %%
import os
from google.colab import _import_hooks

# Get current notebook name
notebook_path = os.path.basename(os.path.realpath("Datset_Loading_Final.ipynb"))
print(notebook_path)
# Out:
# Datset_Loading_Final.ipynb

# %%
# !git add "Datset_Loading_Final.ipynb"
# !git commit -m "Add current Colab notebook"
# Out:
# [master (root-commit) 205fb7b] Add current Colab notebook
#  1 file changed, 1 insertion(+)
#  create mode 100644 Datset_Loading_Final.ipynb

# %%
# !git config --global user.email "dhanushdshekar006@gmail.com"
# !git config --global user.name "Dhanush006"

# %%
# !git remote -v
# Out:
# origin	https://github.com/Dhanush006/DCASE23_Task2_Vehicle_Sound_Event_Detection.git (fetch)
# origin	https://github.com/Dhanush006/DCASE23_Task2_Vehicle_Sound_Event_Detection.git (push)

# %%
# !git push origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'origin'

# %%
# !git remote add origin https://github.com/Dhanush006/DCASE23_Task2_Vehicle_Sound_Event_Detection.git

# %%
# !git branch -M main      # rename current branch to main if needed
